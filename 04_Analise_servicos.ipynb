# %%
import pandas as pd
import missingno as msno

# %%
# Ler o arquivo Parquet
df_c = pd.read_parquet('Dados/metricas_Servicos.parquet')
df_c.head()
# Out:
#              CNPJ  Centralidade de Grau Norm  Comunidade
# 0  53282207000162                   0.055048           0
# 1  52856313000140                   0.019270           1
# 2  52923004000145                   0.013536           1
# 3  53196264000129                   0.005945           2
# 4  53310071000157                   0.003344           1

# %%
import pandas as pd
# Ler o arquivo Parquet
df = pd.read_parquet('Dados/df_ativas_ultimo_trimestre_2023.parquet')
df.head()
# Out:
#              CNPJ  UF MUNICIPIO       CEP DataSituacaoCadastral DataCadastro  \
# 0  42804324000394  SP      2941  15315000            2023-11-03   2023-11-03
# 1  42806249000481  MG      4371  32040027            2023-11-14   2023-11-14
# 2  42879032000230  BA      3873  44445450            2023-11-14   2023-11-14
# 3  43952585000233  SP      6839  15630000            2023-11-10   2023-11-10
# 4  43975859000200  SP      6645  12614899            2023-10-05   2023-10-05
#
#     Porte CNAE_Principal                  CNAE_Secundario MUN_COD_IBGE  \
# 0  DEMAIS        0151201                          0115600      3549250
# 1  DEMAIS        4635499          4635402,4723700,4789001      3118601
# 2      ME        3101200  4752100,4753900,4754701,4754702      2928703
# 3  DEMAIS        0139306                             None      3536901
# 4  DEMAIS        0121101                  0151201,0151202      3527207
#
#            DESC_MUNICIPIO COD_RGI                NOME_RGI         Setor  \
# 0     São João de Iracema  350029           Fernandópolis  Agropecuaria
# 1                Contagem  310001          Belo Horizonte      Comercio
# 2  Santo Antônio de Jesus  290003  Santo Antônio de Jesus     Industria
# 3            Pedranópolis  350029           Fernandópolis  Agropecuaria
# 4                  Lorena  350052           Guaratinguetá  Agropecuaria
#
#      Região                           Descricao_CNAE_Principal CNAE_Divisão  \
# 0   Sudeste                      Criação de bovinos para corte           01
# 1   Sudeste  Comércio atacadista de bebidas não especificad...           46
# 2  Nordeste  Fabricação de móveis com predominância de madeira           31
# 3   Sudeste                             Cultivo de seringueira           01
# 4   Sudeste                       Horticultura, exceto morango           01
#
#                                    Divisão_Descrição
# 0      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS
# 1  COMÉRCIO POR ATACADO, EXCETO VEÍCULOS AUTOMOTO...
# 2                               FABRICAÇÃO DE MÓVEIS
# 3      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS
# 4      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS

# %%
df = df.merge(df_c, on='CNPJ')

# %%
df.tail()
# Out:
#                  CNPJ  UF MUNICIPIO       CEP DataSituacaoCadastral  \
# 18834  53314109000160  SP      7107  01452001            2023-12-27
# 18835  53320747000193  MT      9067  78050200            2023-12-28
# 18836  53328748000184  SP      7097  15061510            2023-12-29
# 18837  53330032000111  RS      8755  99470000            2023-12-29
# 18838  53333029000151  PR      7535  80540400            2023-12-31
#
#       DataCadastro Porte CNAE_Principal  \
# 18834   2023-12-27    ME        7733100
# 18835   2023-12-28    ME        8630503
# 18836   2023-12-29    ME        6209100
# 18837   2023-12-29    ME        8630504
# 18838   2023-12-31    ME        9001902
#
#                                        CNAE_Secundario MUN_COD_IBGE  \
# 18834                                          6204000      3550308
# 18835                          8610102,8610101,8630599      5103403
# 18836  4751201,4789004,6202300,6203100,6319400,7490104      3549805
# 18837                                             None      4312658
# 18838                          8230001,9001999,9329899      4106902
#
#               DESC_MUNICIPIO COD_RGI               NOME_RGI     Setor  \
# 18834              São Paulo  350001              São Paulo  Servicos
# 18835                 Cuiabá  510001                 Cuiabá  Servicos
# 18836  São José do Rio Preto  350025  São José do Rio Preto  Servicos
# 18837           Não-Me-Toque  430028              Carazinho  Servicos
# 18838               Curitiba  410001               Curitiba  Servicos
#
#              Região                           Descricao_CNAE_Principal  \
# 18834       Sudeste  Aluguel de máquinas e equipamentos para escrit...
# 18835  Centro_Oeste  Atividade médica ambulatorial restrita a consu...
# 18836       Sudeste  Suporte técnico, manutenção e outros serviços ...
# 18837           Sul                             Atividade odontológica
# 18838           Sul                                   Produção musical
#
#       CNAE_Divisão                                  Divisão_Descrição  \
# 18834           77  ALUGUÉIS NÃO IMOBILIÁRIOS E GESTÃO DE ATIVOS I...
# 18835           86               ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA
# 18836           62  ATIVIDADES DOS SERVIÇOS DE TECNOLOGIA DA INFOR...
# 18837           86               ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA
# 18838           90  ATIVIDADES ARTÍSTICAS, CRIATIVAS E DE ESPETÁCULOS
#
#        Centralidade de Grau Norm  Comunidade
# 18834                   0.138656           3
# 18835                   0.056588           0
# 18836                   0.018314           1
# 18837                   0.022932           8
# 18838                   0.027763           1

# %%
df.describe()
# Out:
#             DataSituacaoCadastral                DataCadastro  \
# count                       18839                       18839
# mean   2023-11-13 21:21:55.674929  2023-11-13 21:21:55.674929
# min           2023-10-02 00:00:00         2023-10-02 00:00:00
# 25%           2023-10-23 00:00:00         2023-10-23 00:00:00
# 50%           2023-11-14 00:00:00         2023-11-14 00:00:00
# 75%           2023-12-06 00:00:00         2023-12-06 00:00:00
# max           2023-12-31 00:00:00         2023-12-31 00:00:00
# std                           NaN                         NaN
#
#        Centralidade de Grau Norm    Comunidade
# count               18839.000000  18839.000000
# mean                    0.044882      3.308615
# min                     0.000849      0.000000
# 25%                     0.011201      1.000000
# 50%                     0.026542      2.000000
# 75%                     0.052341      5.000000
# max                     0.199331     13.000000
# std                     0.049951      3.162779

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
# Agrupar os dados por Comunidade, UF, Porte e CNAE_Divisão
df_grouped = df.groupby(['Comunidade', 'Região', 'Porte', 'Divisão_Descrição']).size().reset_index(name='counts')

# Calcular as porcentagens para cada característica dentro de cada Comunidade
df_grouped['percent'] = df_grouped.groupby('Comunidade')['counts'].transform(lambda x: (x / x.sum()) * 100)

# Filtrar apenas as linhas com valores relevantes
df_grouped_filtered = df_grouped

# Reformatar a tabela para que as colunas sejam as Comunidades e os índices as combinações de UF, Porte, e CNAE_Divisão
df_pivot = df_grouped_filtered.pivot_table(index=['Região', 'Porte', 'Divisão_Descrição'], columns='Comunidade', values='percent', fill_value=0)
# Função para aplicar um gradiente de cores com base nos valores
def color_scale(val):
    if val <= 10:
        return #'background-color: #ffcccc'  # Vermelho claro para valores baixos
    elif val <= 20:
        return 'background-color: #ff9966'  # Laranja claro
    elif val <= 30:
        return 'background-color: #ffcc66'  # Amarelo claro
    elif val <= 40:
        return 'background-color: #99cc66'  # Verde claro
    elif val <= 50:
        return 'background-color: #66cc99'  # Verde mais intenso
    else:
        return 'background-color: #66ff66'  # Verde para os valores mais altos

# Aplicar o novo estilo na tabela e arredondar para porcentagens
styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)

# Exibir a tabela com gradiente de cores condicional e porcentagens arredondadas
styled_df
# Out:
# C:\Users\fmarc\AppData\Local\Temp\ipykernel_17816\2390212438.py:28: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)
# <style type="text/css">
# #T_9d8f7_row26_col10, #T_9d8f7_row33_col8, #T_9d8f7_row33_col9, #T_9d8f7_row53_col4, #T_9d8f7_row56_col12, #T_9d8f7_row60_col5, #T_9d8f7_row87_col7, #T_9d8f7_row94_col0, #T_9d8f7_row94_col9, #T_9d8f7_row114_col4, #T_9d8f7_row181_col2, #T_9d8f7_row220_col3, #T_9d8f7_row225_col6, #T_9d8f7_row228_col3, #T_9d8f7_row240_col11, #T_9d8f7_row286_col0, #T_9d8f7_row290_col6, #T_9d8f7_row294_col13 {
#   background-color: #ff9966;
# }
# #T_9d8f7_row51_col11, #T_9d8f7_row87_col10, #T_9d8f7_row94_col8, #T_9d8f7_row112_col11, #T_9d8f7_row117_col12, #T_9d8f7_row213_col7, #T_9d8f7_row248_col3, #T_9d8f7_row279_col10, #T_9d8f7_row286_col8, #T_9d8f7_row286_col9, #T_9d8f7_row302_col11, #T_9d8f7_row304_col4, #T_9d8f7_row307_col12 {
#   background-color: #ffcc66;
# }
# #T_9d8f7_row103_col13, #T_9d8f7_row213_col10, #T_9d8f7_row220_col8, #T_9d8f7_row229_col13, #T_9d8f7_row242_col4, #T_9d8f7_row246_col12, #T_9d8f7_row253_col5, #T_9d8f7_row312_col5 {
#   background-color: #99cc66;
# }
# #T_9d8f7_row220_col0 {
#   background-color: #66ff66;
# }
# #T_9d8f7_row220_col9 {
#   background-color: #66cc99;
# }
# </style>
# <table id="T_9d8f7">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Comunidade</th>
#       <th id="T_9d8f7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9d8f7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9d8f7_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9d8f7_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9d8f7_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_9d8f7_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_9d8f7_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_9d8f7_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_9d8f7_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_9d8f7_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_9d8f7_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_9d8f7_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_9d8f7_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_9d8f7_level0_col13" class="col_heading level0 col13" >13</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Região</th>
#       <th class="index_name level1" >Porte</th>
#       <th class="index_name level2" >Divisão_Descrição</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d8f7_level0_row0" class="row_heading level0 row0" rowspan="61">Centro_Oeste</th>
#       <th id="T_9d8f7_level1_row0" class="row_heading level1 row0" rowspan="24">EPP</th>
#       <th id="T_9d8f7_level2_row0" class="row_heading level2 row0" >ALIMENTAÇÃO</th>
#       <td id="T_9d8f7_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_9d8f7_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_9d8f7_row0_col2" class="data row0 col2" >1.03%</td>
#       <td id="T_9d8f7_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_9d8f7_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_9d8f7_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_9d8f7_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_9d8f7_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_9d8f7_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_9d8f7_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_9d8f7_row0_col10" class="data row0 col10" >0.00%</td>
#       <td id="T_9d8f7_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_9d8f7_row0_col12" class="data row0 col12" >0.00%</td>
#       <td id="T_9d8f7_row0_col13" class="data row0 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9d8f7_level2_row1" class="row_heading level2 row1" >ALUGUÉIS NÃO IMOBILIÁRIOS E GESTÃO DE ATIVOS INTANGÍVEIS NÃO FINANCEIROS</th>
#       <td id="T_9d8f7_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_9d8f7_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_9d8f7_row1_col2" class="data row1 col2" >0.12%</td>
#       <td id="T_9d8f7_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_9d8f7_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_9d8f7_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_9d8f7_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_9d8f7_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_9d8f7_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_9d8f7_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_9d8f7_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_9d8f7_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_9d8f7_row1_col12" class="data row1 col12" >0.00%</td>
#       <td id="T_9d8f7_row1_col13" class="data row1 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9d8f7_level2_row2" class="row_heading level2 row2" >ARMAZENAMENTO E ATIVIDADES AUXILIARES DOS TRANSPORTES</th>
#       <td id="T_9d8f7_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_9d8f7_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_9d8f7_row2_col2" class="data row2 col2" >0.04%</td>
#       <td id="T_9d8f7_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_9d8f7_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_9d8f7_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_9d8f7_row2_col6" class="data row2 col6" >0.00%</td>
#       <td id="T_9d8f7_row2_col7" class="data row2 col7" >0.00%</td>
#       <td id="T_9d8f7_row2_col8" class="data row2 col8" >0.00%</td>
#       <td id="T_9d8f7_row2_col9" class="data row2 col9" >0.00%</td>
#       <td id="T_9d8f7_row2_col10" class="data row2 col10" >0.00%</td>
#       <td id="T_9d8f7_row2_col11" class="data row2 col11" >0.00%</td>
#       <td id="T_9d8f7_row2_col12" class="data row2 col12" >0.00%</td>
#       <td id="T_9d8f7_row2_col13" class="data row2 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9d8f7_level2_row3" class="row_heading level2 row3" >ATIVIDADES AUXILIARES DOS SERVIÇOS FINANCEIROS, SEGUROS, PREVIDÊNCIA COMPLEMENTAR E PLANOS DE SAÚDE</th>
#       <td id="T_9d8f7_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_9d8f7_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_9d8f7_row3_col2" class="data row3 col2" >0.04%</td>
#       <td id="T_9d8f7_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_9d8f7_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_9d8f7_row3_col5" class="data row3 col5" >0.00%</td>
#       <td id="T_9d8f7_row3_col6" class="data row3 col6" >0.00%</td>
#       <td id="T_9d8f7_row3_col7" class="data row3 col7" >0.00%</td>
#       <td id="T_9d8f7_row3_col8" class="data row3 col8" >0.00%</td>
#       <td id="T_9d8f7_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_9d8f7_row3_col10" class="data row3 col10" >0.00%</td>
#       <td id="T_9d8f7_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_9d8f7_row3_col12" class="data row3 col12" >0.00%</td>
#       <td id="T_9d8f7_row3_col13" class="data row3 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9d8f7_level2_row4" class="row_heading level2 row4" >ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA</th>
#       <td id="T_9d8f7_row4_col0" class="data row4 col0" >0.00%</td>
#       <td id="T_9d8f7_row4_col1" class="data row4 col

# %%
# Agrupar os dados por Comunidade, UF, Porte e CNAE_Divisão
df_grouped = df.groupby(['Comunidade', 'Região', 'Porte', 'Divisão_Descrição']).size().reset_index(name='counts')

# Calcular as porcentagens para cada característica dentro de cada Comunidade
df_grouped['percent'] = df_grouped.groupby('Comunidade')['counts'].transform(lambda x: (x / x.sum()) * 100)

# Filtrar apenas as linhas com valores relevantes (acima de 5%)
df_grouped_filtered = df_grouped[df_grouped['percent'] > 5]

# Reformatar a tabela para que as colunas sejam as Comunidades e os índices as combinações de UF, Porte, e CNAE_Divisão
df_pivot = df_grouped_filtered.pivot_table(index=['Região', 'Porte', 'Divisão_Descrição'], columns='Comunidade', values='percent', fill_value=0)
# Função para aplicar um gradiente de cores com base nos valores
def color_scale(val):
    if val <= 10:
        return #'background-color: #ffcccc'  # Vermelho claro para valores baixos
    elif val <= 20:
        return 'background-color: #ff9966'  # Laranja claro
    elif val <= 30:
        return 'background-color: #ffcc66'  # Amarelo claro
    elif val <= 40:
        return 'background-color: #99cc66'  # Verde claro
    elif val <= 50:
        return 'background-color: #66cc99'  # Verde mais intenso
    else:
        return 'background-color: #66ff66'  # Verde para os valores mais altos

# Aplicar o novo estilo na tabela e arredondar para porcentagens
styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)

# Exibir a tabela com gradiente de cores condicional e porcentagens arredondadas
styled_df
# Out:
# C:\Users\fmarc\AppData\Local\Temp\ipykernel_17816\1452461795.py:28: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)
# <style type="text/css">
# #T_bfa2e_row0_col10, #T_bfa2e_row1_col8, #T_bfa2e_row1_col9, #T_bfa2e_row5_col4, #T_bfa2e_row6_col12, #T_bfa2e_row7_col5, #T_bfa2e_row8_col7, #T_bfa2e_row9_col0, #T_bfa2e_row9_col9, #T_bfa2e_row13_col4, #T_bfa2e_row19_col2, #T_bfa2e_row22_col3, #T_bfa2e_row23_col6, #T_bfa2e_row24_col3, #T_bfa2e_row26_col11, #T_bfa2e_row32_col0, #T_bfa2e_row33_col6, #T_bfa2e_row34_col13 {
#   background-color: #ff9966;
# }
# #T_bfa2e_row4_col11, #T_bfa2e_row8_col10, #T_bfa2e_row9_col8, #T_bfa2e_row12_col11, #T_bfa2e_row14_col12, #T_bfa2e_row21_col7, #T_bfa2e_row29_col3, #T_bfa2e_row31_col10, #T_bfa2e_row32_col8, #T_bfa2e_row32_col9, #T_bfa2e_row35_col11, #T_bfa2e_row36_col4, #T_bfa2e_row37_col12 {
#   background-color: #ffcc66;
# }
# #T_bfa2e_row11_col13, #T_bfa2e_row21_col10, #T_bfa2e_row22_col8, #T_bfa2e_row25_col13, #T_bfa2e_row27_col4, #T_bfa2e_row28_col12, #T_bfa2e_row30_col5, #T_bfa2e_row39_col5 {
#   background-color: #99cc66;
# }
# #T_bfa2e_row22_col0 {
#   background-color: #66ff66;
# }
# #T_bfa2e_row22_col9 {
#   background-color: #66cc99;
# }
# </style>
# <table id="T_bfa2e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Comunidade</th>
#       <th id="T_bfa2e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_bfa2e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_bfa2e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_bfa2e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_bfa2e_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_bfa2e_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_bfa2e_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_bfa2e_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_bfa2e_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_bfa2e_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_bfa2e_level0_col10" class="col_heading level0 col10" >10</th>
#       <th id="T_bfa2e_level0_col11" class="col_heading level0 col11" >11</th>
#       <th id="T_bfa2e_level0_col12" class="col_heading level0 col12" >12</th>
#       <th id="T_bfa2e_level0_col13" class="col_heading level0 col13" >13</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Região</th>
#       <th class="index_name level1" >Porte</th>
#       <th class="index_name level2" >Divisão_Descrição</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfa2e_level0_row0" class="row_heading level0 row0" rowspan="8">Centro_Oeste</th>
#       <th id="T_bfa2e_level1_row0" class="row_heading level1 row0" rowspan="8">ME</th>
#       <th id="T_bfa2e_level2_row0" class="row_heading level2 row0" >ALIMENTAÇÃO</th>
#       <td id="T_bfa2e_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_bfa2e_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_bfa2e_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_bfa2e_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_bfa2e_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_bfa2e_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_bfa2e_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_bfa2e_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_bfa2e_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_bfa2e_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_bfa2e_row0_col10" class="data row0 col10" >10.53%</td>
#       <td id="T_bfa2e_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_bfa2e_row0_col12" class="data row0 col12" >0.00%</td>
#       <td id="T_bfa2e_row0_col13" class="data row0 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bfa2e_level2_row1" class="row_heading level2 row1" >ATIVIDADES DE ATENÇÃO À SAÚDE HUMANA</th>
#       <td id="T_bfa2e_row1_col0" class="data row1 col0" >7.25%</td>
#       <td id="T_bfa2e_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_bfa2e_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_bfa2e_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_bfa2e_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_bfa2e_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_bfa2e_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_bfa2e_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_bfa2e_row1_col8" class="data row1 col8" >14.21%</td>
#       <td id="T_bfa2e_row1_col9" class="data row1 col9" >14.44%</td>
#       <td id="T_bfa2e_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_bfa2e_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_bfa2e_row1_col12" class="data row1 col12" >0.00%</td>
#       <td id="T_bfa2e_row1_col13" class="data row1 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bfa2e_level2_row2" class="row_heading level2 row2" >ATIVIDADES DE SEDES DE EMPRESAS E DE CONSULTORIA EM GESTÃO EMPRESARIAL</th>
#       <td id="T_bfa2e_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_bfa2e_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_bfa2e_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_bfa2e_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_bfa2e_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_bfa2e_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_bfa2e_row2_col6" class="data row2 col6" >5.59%</td>
#       <td id="T_bfa2e_row2_col7" class="data row2 col7" >0.00%</td>
#       <td id="T_bfa2e_row2_col8" class="data row2 col8" >0.00%</td>
#       <td id="T_bfa2e_row2_col9" class="data row2 col9" >0.00%</td>
#       <td id="T_bfa2e_row2_col10" class="data row2 col10" >0.00%</td>
#       <td id="T_bfa2e_row2_col11" class="data row2 col11" >0.00%</td>
#       <td id="T_bfa2e_row2_col12" class="data row2 col12" >0.00%</td>
#       <td id="T_bfa2e_row2_col13" class="data row2 col13" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_bfa2e_level2_row3" class="row_heading level2 row3" >ATIVIDADES ESPORTIVAS E DE RECREAÇÃO E LAZER</th>
#       <td id="T_bfa2e_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_bfa2e_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_bfa2e_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_bfa2e_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_bfa2e_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_bfa2e_row3_col5" class="data row3 col5" >0.00%</td>
#       <td id="T_bfa2e_row3_col6" class="data row3 col6" >0.00%</td>
#       <td id="T_bfa2e_row3_col7" class="data row3 col7" >0.00%</td>
#       <td id="T_bfa2e_row3_col8" class="data row3 col8" >0.00%</td>
#       <td id="T_bfa2e_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_bfa2e_row3_col10" class="data row3 col10" >0.00%</td>
#       <td id="T_bfa2e_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_bfa2e_row3_col12" class="data row3 col12" >0.00%</td>
#       <td id="T_bfa2e_row3_col13" class="data row3 col13" >8.08%</td>
#     </tr>
#     <tr>
#       <th id="T_bfa2e_level2_row4" class="row_heading level2 row4" >OUTRAS ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS</th>
#       <td id="T_bfa2e_row4_col0" class="data row4 col0" >0.00%</td>
#       <td id="T_bfa2e_row4_col1" class="data row4 col1" >0.00%</td>
#       <td id="T_bfa2e_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id=

# %%
# Contagem de registros por comunidade
contagem_comunidades = df['Comunidade'].value_counts().reset_index()

# Renomear as colunas para clareza
contagem_comunidades.columns = ['Comunidade', 'Count']

# Ordenar pela contagem em ordem decrescente
contagem_comunidades_sorted = contagem_comunidades.sort_values(by='Count', ascending=False)

# Exibir o resultado
contagem_comunidades_sorted
# Out:
#     Comunidade  Count
# 0            1   6815
# 1            3   3422
# 2            2   2424
# 3            7   1213
# 4            6   1020
# 5            0   1007
# 6            9    561
# 7           12    483
# 8           10    399
# 9            8    387
# 10           5    381
# 11           4    366
# 12          13    260
# 13          11    101

# %%
# Calculando a média da centralidade de grau por comunidade, ignorando NaN
media_centralidade = df.groupby('Comunidade', dropna=True)['Centralidade de Grau Norm'].mean()

# Exibindo o resultado
print(media_centralidade)
# Out:
# Comunidade
# 0     0.067827
# 1     0.016014
# 2     0.017712
# 3     0.134959
# 4     0.028426
# 5     0.021808
# 6     0.040813
# 7     0.035303
# 8     0.027358
# 9     0.033180
# 10    0.026697
# 11    0.005931
# 12    0.031619
# 13    0.017070
# Name: Centralidade de Grau Norm, dtype: float64
