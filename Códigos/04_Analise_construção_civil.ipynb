# %%
import pandas as pd
import missingno as msno

# %%
# Ler o arquivo Parquet
df = pd.read_parquet('Dados/df_ativas_ultimo_trimestre_2023.parquet')
df.head()
# Out:
#              CNPJ  UF MUNICIPIO       CEP DataSituacaoCadastral DataCadastro  \
# 0  42804324000394  SP      2941  15315000            2023-11-03   2023-11-03
# 1  42806249000481  MG      4371  32040027            2023-11-14   2023-11-14
# 2  42879032000230  BA      3873  44445450            2023-11-14   2023-11-14
# 3  43952585000233  SP      6839  15630000            2023-11-10   2023-11-10
# 4  43975859000200  SP      6645  12614899            2023-10-05   2023-10-05
#
#     Porte CNAE_Principal                  CNAE_Secundario MUN_COD_IBGE  \
# 0  DEMAIS        0151201                          0115600      3549250
# 1  DEMAIS        4635499          4635402,4723700,4789001      3118601
# 2      ME        3101200  4752100,4753900,4754701,4754702      2928703
# 3  DEMAIS        0139306                             None      3536901
# 4  DEMAIS        0121101                  0151201,0151202      3527207
#
#            DESC_MUNICIPIO COD_RGI                NOME_RGI         Setor  \
# 0     São João de Iracema  350029           Fernandópolis  Agropecuaria
# 1                Contagem  310001          Belo Horizonte      Comercio
# 2  Santo Antônio de Jesus  290003  Santo Antônio de Jesus     Industria
# 3            Pedranópolis  350029           Fernandópolis  Agropecuaria
# 4                  Lorena  350052           Guaratinguetá  Agropecuaria
#
#      Região                           Descricao_CNAE_Principal CNAE_Divisão  \
# 0   Sudeste                      Criação de bovinos para corte           01
# 1   Sudeste  Comércio atacadista de bebidas não especificad...           46
# 2  Nordeste  Fabricação de móveis com predominância de madeira           31
# 3   Sudeste                             Cultivo de seringueira           01
# 4   Sudeste                       Horticultura, exceto morango           01
#
#                                    Divisão_Descrição
# 0      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS
# 1  COMÉRCIO POR ATACADO, EXCETO VEÍCULOS AUTOMOTO...
# 2                               FABRICAÇÃO DE MÓVEIS
# 3      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS
# 4      AGRICULTURA, PECUÁRIA E SERVIÇOS RELACIONADOS

# %%
# Ler o arquivo Parquet
df_m= pd.read_parquet('metricas_globais_Construcao Civil.parquet')
df_m.head()
# Out:
#               Setor  Número de Nós  Número de Arestas  \
# 0  Construcao Civil           7513            3681867
#
#    Coeficiente de Agrupamento Médio  Comprimento Médio do Caminho (Ponderado)  \
# 0                          0.824096                                  5.047816
#
#    Diâmetro (Ponderado)  Densidade  Número de Comunidades
# 0                   9.5   0.130476                      7

# %%
# Ler o arquivo Parquet
df_c = pd.read_parquet('metricas_Construcao Civil.parquet')
df_c.head()
# Out:
#              CNPJ  Centralidade de Grau Ponderada  Comunidade
# 0  52467931000106                        0.097444           0
# 1  52468558000108                        0.675053           1
# 2  52468910000105                        0.027356           0
# 3  52468975000142                        0.075812           0
# 4  52469169000199                        0.666600           1

# %%
df_c["Centralidade de Grau Ponderada"].max()
# Out:
# 0.9018237486687966

# %%
df.tail()
# Out:
#                   CNPJ  UF MUNICIPIO       CEP DataSituacaoCadastral  \
# 211519  54569187000178  MT      9067  78043409            2023-10-25
# 211520  54569992000100  RS      8681  95675056            2023-12-15
# 211521  54570021000171  MA      0803  65900410            2023-11-21
# 211522  54570394000142  CE      1405  62270000            2023-12-13
# 211523  54572263000102  ES      5623  29305352            2023-11-30
#
#        DataCadastro   Porte CNAE_Principal CNAE_Secundario MUN_COD_IBGE  \
# 211519   2023-10-25  DEMAIS        6911701            None      5103403
# 211520   2023-12-15  DEMAIS        8112500            None      4309100
# 211521   2023-11-21  DEMAIS        6911701            None      2105302
# 211522   2023-12-13  DEMAIS        9492800            None      2305209
# 211523   2023-11-30  DEMAIS        9492800            None      3201209
#
#                  DESC_MUNICIPIO COD_RGI                 NOME_RGI     Setor  \
# 211519                   Cuiabá  510001                   Cuiabá  Servicos
# 211520                  Gramado  430036            Caxias do Sul  Servicos
# 211521               Imperatriz  210019               Imperatriz  Servicos
# 211522              Hidrolândia  230015                   Sobral  Servicos
# 211523  Cachoeiro de Itapemirim  320007  Cachoeiro de Itapemirim  Servicos
#
#               Região              Descricao_CNAE_Principal CNAE_Divisão  \
# 211519  Centro_Oeste                 Serviços advocatícios           69
# 211520           Sul                  Condomínios prediais           81
# 211521      Nordeste                 Serviços advocatícios           69
# 211522      Nordeste  Atividades de organizações políticas           94
# 211523       Sudeste  Atividades de organizações políticas           94
#
#                                         Divisão_Descrição
# 211519  ATIVIDADES JURÍDICAS, DE CONTABILIDADE E DE AU...
# 211520  SERVIÇOS PARA EDIFÍCIOS E ATIVIDADES PAISAGÍST...
# 211521  ATIVIDADES JURÍDICAS, DE CONTABILIDADE E DE AU...
# 211522            ATIVIDADES DE ORGANIZAÇÕES ASSOCIATIVAS
# 211523            ATIVIDADES DE ORGANIZAÇÕES ASSOCIATIVAS

# %%
df.describe()
# Out:
#             DataSituacaoCadastral                DataCadastro
# count                      211524                      211524
# mean   2023-11-13 17:51:30.645033  2023-11-13 17:50:51.840926
# min           2023-10-02 00:00:00         2023-10-02 00:00:00
# 25%           2023-10-23 00:00:00         2023-10-23 00:00:00
# 50%           2023-11-14 00:00:00         2023-11-14 00:00:00
# 75%           2023-12-06 00:00:00         2023-12-06 00:00:00
# max           2023-12-31 00:00:00         2023-12-31 00:00:00

# %%
df = df.merge(df_c, on='CNPJ')

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df
# Out:
#                 CNPJ  UF MUNICIPIO       CEP DataSituacaoCadastral  \
# 0     52467931000106  MG      4159  37220000            2023-10-09
# 1     52468558000108  SE      3105  49015270            2023-10-09
# 2     52468910000105  CE      1389  60160196            2023-10-09
# 3     52468975000142  RJ      6001  22440035            2023-10-09
# 4     52469169000199  AL      2701  57490000            2023-10-09
# ...              ...  ..       ...       ...                   ...
# 7508  53274385000141  SP      7107  04429260            2023-12-20
# 7509  53279747000197  SP      7107  03378060            2023-12-21
# 7510  53280136000169  RN      1761  59075240            2023-12-21
# 7511  53296878000182  SP      6563  08572210            2023-12-23
# 7512  53299785000101  RJ      5803  28981675            2023-12-26
#
#      DataCadastro Porte CNAE_Principal  \
# 0      2023-10-09    ME        4330404
# 1      2023-10-09    ME        4120400
# 2      2023-10-09   EPP        4330499
# 3      2023-10-09   EPP        4399101
# 4      2023-10-09    ME        4120400
# ...           ...   ...            ...
# 7508   2023-12-20    ME        4399103
# 7509   2023-12-21    ME        4330499
# 7510   2023-12-21    ME        4399103
# 7511   2023-12-23   EPP        4321500
# 7512   2023-12-26    ME        4120400
#
#                                         CNAE_Secundario MUN_COD_IBGE  \
# 0                                                  None      3108008
# 1                                                  None      2800308
# 2                                               4330402      2304400
# 3       4744099,4754703,4759899,7119703,7490104,8599604      3304557
# 4     3313901,3313902,3313999,3314702,3314704,331470...      2700102
# ...                                                 ...          ...
# 7508                            4330404,4330401,4399101      3550308
# 7509                                               None      3550308
# 7510    4120400,4321500,4322301,4330404,4330405,4330499      2408102
# 7511                                               None      3523107
# 7512  4211101,4222701,4292801,4313400,4321500,432230...      3300209
#
#        DESC_MUNICIPIO COD_RGI         NOME_RGI             Setor    Região  \
# 0         Bom Sucesso  310043           Lavras  Construcao Civil   Sudeste
# 1             Aracaju  280001          Aracaju  Construcao Civil  Nordeste
# 2           Fortaleza  230001        Fortaleza  Construcao Civil  Nordeste
# 3      Rio de Janeiro  330001   Rio de Janeiro  Construcao Civil   Sudeste
# 4         Água Branca  270009  Delmiro Gouveia  Construcao Civil  Nordeste
# ...               ...     ...              ...               ...       ...
# 7508        São Paulo  350001        São Paulo  Construcao Civil   Sudeste
# 7509        São Paulo  350001        São Paulo  Construcao Civil   Sudeste
# 7510            Natal  240001            Natal  Construcao Civil  Nordeste
# 7511  Itaquaquecetuba  350001        São Paulo  Construcao Civil   Sudeste
# 7512         Araruama  330013        Cabo Frio  Construcao Civil   Sudeste
#
#                        Descricao_CNAE_Principal CNAE_Divisão  \
# 0     Serviços de pintura de edifícios em geral           43
# 1                       Construção de edifícios           41
# 2      Outras obras de acabamento da construção           43
# 3                        Administração de obras           43
# 4                       Construção de edifícios           41
# ...                                         ...          ...
# 7508                         Obras de alvenaria           43
# 7509   Outras obras de acabamento da construção           43
# 7510                         Obras de alvenaria           43
# 7511           Instalação e manutenção elétrica           43
# 7512                    Construção de edifícios           41
#
#                             Divisão_Descrição  Centralidade de Grau Ponderada  \
# 0     SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.097444
# 1                     CONSTRUÇÃO DE EDIFÍCIOS                        0.675053
# 2     SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.027356
# 3     SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.075812
# 4                     CONSTRUÇÃO DE EDIFÍCIOS                        0.666600
# ...                                       ...                             ...
# 7508  SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.583001
# 7509  SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.402822
# 7510  SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.268770
# 7511  SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO                        0.127330
# 7512                  CONSTRUÇÃO DE EDIFÍCIOS                        0.667865
#
#       Comunidade
# 0              0
# 1              1
# 2              0
# 3              0
# 4              1
# ...          ...
# 7508           4
# 7509           0
# 7510           4
# 7511           0
# 7512           1
#
# [7513 rows x 20 columns]

# %%
# Agrupar os dados por Comunidade, UF, Porte e CNAE_Divisão
df_grouped = df.groupby(['Comunidade', 'Região', 'Porte', 'Divisão_Descrição']).size().reset_index(name='counts')

# Calcular as porcentagens para cada característica dentro de cada Comunidade
df_grouped['percent'] = df_grouped.groupby('Comunidade')['counts'].transform(lambda x: (x / x.sum()) * 100)

# Filtrar apenas as linhas com valores relevantes
df_grouped_filtered = df_grouped

# Reformatar a tabela para que as colunas sejam as Comunidades e os índices as combinações de UF, Porte, e CNAE_Divisão
df_pivot = df_grouped_filtered.pivot_table(index=['Região', 'Porte', 'Divisão_Descrição'], columns='Comunidade', values='percent', fill_value=0)
# Função para aplicar um gradiente de cores com base nos valores
def color_scale(val):
    if val <= 10:
        return #'background-color: #ffcccc'  # Vermelho claro para valores baixos
    elif val <= 20:
        return 'background-color: #ff9966'  # Laranja claro
    elif val <= 30:
        return 'background-color: #ffcc66'  # Amarelo claro
    elif val <= 40:
        return 'background-color: #99cc66'  # Verde claro
    elif val <= 50:
        return 'background-color: #66cc99'  # Verde mais intenso
    else:
        return 'background-color: #66ff66'  # Verde para os valores mais altos

# Aplicar o novo estilo na tabela e arredondar para porcentagens
styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)

# Exibir a tabela com gradiente de cores condicional e porcentagens arredondadas
styled_df
# Out:
# C:\Users\fmarc\AppData\Local\Temp\ipykernel_17412\2390212438.py:28: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)
# <style type="text/css">
# #T_825c0_row0_col2, #T_825c0_row3_col1, #T_825c0_row4_col6, #T_825c0_row5_col3, #T_825c0_row5_col5, #T_825c0_row9_col6, #T_825c0_row10_col3, #T_825c0_row18_col0, #T_825c0_row22_col2, #T_825c0_row26_col0 {
#   background-color: #ff9966;
# }
# #T_825c0_row6_col2, #T_825c0_row8_col1, #T_825c0_row24_col1, #T_825c0_row26_col3, #T_825c0_row26_col4 {
#   background-color: #ffcc66;
# }
# #T_825c0_row16_col2, #T_825c0_row19_col1, #T_825c0_row20_col6, #T_825c0_row21_col0, #T_825c0_row21_col5, #T_825c0_row25_col6, #T_825c0_row26_col5 {
#   background-color: #99cc66;
# }
# #T_825c0_row21_col3 {
#   background-color: #66cc99;
# }
# #T_825c0_row21_col4 {
#   background-color: #66ff66;
# }
# </style>
# <table id="T_825c0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Comunidade</th>
#       <th id="T_825c0_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_825c0_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_825c0_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_825c0_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_825c0_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_825c0_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_825c0_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Região</th>
#       <th class="index_name level1" >Porte</th>
#       <th class="index_name level2" >Divisão_Descrição</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_825c0_level0_row0" class="row_heading level0 row0" rowspan="6">Centro_Oeste</th>
#       <th id="T_825c0_level1_row0" class="row_heading level1 row0" rowspan="3">EPP</th>
#       <th id="T_825c0_level2_row0" class="row_heading level2 row0" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_825c0_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_825c0_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_825c0_row0_col2" class="data row0 col2" >14.61%</td>
#       <td id="T_825c0_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_825c0_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_825c0_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_825c0_row0_col6" class="data row0 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row1" class="row_heading level2 row1" >OBRAS DE INFRAESTRUTURA</th>
#       <td id="T_825c0_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_825c0_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_825c0_row1_col2" class="data row1 col2" >0.15%</td>
#       <td id="T_825c0_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_825c0_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_825c0_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_825c0_row1_col6" class="data row1 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row2" class="row_heading level2 row2" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_825c0_row2_col0" class="data row2 col0" >2.63%</td>
#       <td id="T_825c0_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_825c0_row2_col2" class="data row2 col2" >0.75%</td>
#       <td id="T_825c0_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_825c0_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_825c0_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_825c0_row2_col6" class="data row2 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level1_row3" class="row_heading level1 row3" rowspan="3">ME</th>
#       <th id="T_825c0_level2_row3" class="row_heading level2 row3" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_825c0_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_825c0_row3_col1" class="data row3 col1" >11.93%</td>
#       <td id="T_825c0_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_825c0_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_825c0_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_825c0_row3_col5" class="data row3 col5" >0.00%</td>
#       <td id="T_825c0_row3_col6" class="data row3 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row4" class="row_heading level2 row4" >OBRAS DE INFRAESTRUTURA</th>
#       <td id="T_825c0_row4_col0" class="data row4 col0" >0.80%</td>
#       <td id="T_825c0_row4_col1" class="data row4 col1" >0.00%</td>
#       <td id="T_825c0_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id="T_825c0_row4_col3" class="data row4 col3" >0.00%</td>
#       <td id="T_825c0_row4_col4" class="data row4 col4" >0.00%</td>
#       <td id="T_825c0_row4_col5" class="data row4 col5" >0.00%</td>
#       <td id="T_825c0_row4_col6" class="data row4 col6" >10.05%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row5" class="row_heading level2 row5" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_825c0_row5_col0" class="data row5 col0" >6.82%</td>
#       <td id="T_825c0_row5_col1" class="data row5 col1" >0.00%</td>
#       <td id="T_825c0_row5_col2" class="data row5 col2" >0.00%</td>
#       <td id="T_825c0_row5_col3" class="data row5 col3" >11.00%</td>
#       <td id="T_825c0_row5_col4" class="data row5 col4" >9.42%</td>
#       <td id="T_825c0_row5_col5" class="data row5 col5" >16.61%</td>
#       <td id="T_825c0_row5_col6" class="data row5 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level0_row6" class="row_heading level0 row6" rowspan="5">Nordeste</th>
#       <th id="T_825c0_level1_row6" class="row_heading level1 row6" rowspan="2">EPP</th>
#       <th id="T_825c0_level2_row6" class="row_heading level2 row6" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_825c0_row6_col0" class="data row6 col0" >0.00%</td>
#       <td id="T_825c0_row6_col1" class="data row6 col1" >0.00%</td>
#       <td id="T_825c0_row6_col2" class="data row6 col2" >22.65%</td>
#       <td id="T_825c0_row6_col3" class="data row6 col3" >0.00%</td>
#       <td id="T_825c0_row6_col4" class="data row6 col4" >0.00%</td>
#       <td id="T_825c0_row6_col5" class="data row6 col5" >0.00%</td>
#       <td id="T_825c0_row6_col6" class="data row6 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row7" class="row_heading level2 row7" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_825c0_row7_col0" class="data row7 col0" >1.93%</td>
#       <td id="T_825c0_row7_col1" class="data row7 col1" >0.00%</td>
#       <td id="T_825c0_row7_col2" class="data row7 col2" >1.19%</td>
#       <td id="T_825c0_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_825c0_row7_col4" class="data row7 col4" >0.00%</td>
#       <td id="T_825c0_row7_col5" class="data row7 col5" >0.00%</td>
#       <td id="T_825c0_row7_col6" class="data row7 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level1_row8" class="row_heading level1 row8" rowspan="3">ME</th>
#       <th id="T_825c0_level2_row8" class="row_heading level2 row8" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_825c0_row8_col0" class="data row8 col0" >0.00%</td>
#       <td id="T_825c0_row8_col1" class="data row8 col1" >27.61%</td>
#       <td id="T_825c0_row8_col2" class="data row8 col2" >0.00%</td>
#       <td id="T_825c0_row8_col3" class="data row8 col3" >0.00%</td>
#       <td id="T_825c0_row8_col4" class="data row8 col4" >0.00%</td>
#       <td id="T_825c0_row8_col5" class="data row8 col5" >0.00%</td>
#       <td id="T_825c0_row8_col6" class="data row8 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_825c0_level2_row9" class="row_heading level2 row9" >OBRAS DE INFRAESTRUTURA</th>
#       <td id="T_825c0_row9_col0" class="data row9 col0" >1.24%</td>
#       <td id="T_825c0

# %%
# Agrupar os dados por Comunidade, UF, Porte e CNAE_Divisão
df_grouped = df.groupby(['Comunidade', 'Região', 'Porte', 'Divisão_Descrição']).size().reset_index(name='counts')

# Calcular as porcentagens para cada característica dentro de cada Comunidade
df_grouped['percent'] = df_grouped.groupby('Comunidade')['counts'].transform(lambda x: (x / x.sum()) * 100)

# Filtrar apenas as linhas com valores relevantes (acima de 5%)
df_grouped_filtered = df_grouped[df_grouped['percent'] > 15]

# Reformatar a tabela para que as colunas sejam as Comunidades e os índices as combinações de UF, Porte, e CNAE_Divisão
df_pivot = df_grouped_filtered.pivot_table(index=['Região', 'Porte', 'Divisão_Descrição'], columns='Comunidade', values='percent', fill_value=0)
# Função para aplicar um gradiente de cores com base nos valores
def color_scale(val):
    if val <= 10:
        return #'background-color: #ffcccc'  # Vermelho claro para valores baixos
    elif val <= 20:
        return 'background-color: #ff9966'  # Laranja claro
    elif val <= 30:
        return 'background-color: #ffcc66'  # Amarelo claro
    elif val <= 40:
        return 'background-color: #99cc66'  # Verde claro
    elif val <= 50:
        return 'background-color: #66cc99'  # Verde mais intenso
    else:
        return 'background-color: #66ff66'  # Verde para os valores mais altos

# Aplicar o novo estilo na tabela e arredondar para porcentagens
styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)

# Exibir a tabela com gradiente de cores condicional e porcentagens arredondadas
styled_df
# Out:
# C:\Users\fmarc\AppData\Local\Temp\ipykernel_17412\205827612.py:28: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   styled_df = df_pivot.style.format("{:.2f}%").applymap(color_scale)
# <style type="text/css">
# #T_6e1ad_row0_col5, #T_6e1ad_row3_col6, #T_6e1ad_row4_col3, #T_6e1ad_row11_col0 {
#   background-color: #ff9966;
# }
# #T_6e1ad_row1_col2, #T_6e1ad_row2_col1, #T_6e1ad_row9_col1, #T_6e1ad_row11_col3, #T_6e1ad_row11_col4 {
#   background-color: #ffcc66;
# }
# #T_6e1ad_row5_col2, #T_6e1ad_row6_col1, #T_6e1ad_row7_col6, #T_6e1ad_row8_col0, #T_6e1ad_row8_col5, #T_6e1ad_row10_col6, #T_6e1ad_row11_col5 {
#   background-color: #99cc66;
# }
# #T_6e1ad_row8_col3 {
#   background-color: #66cc99;
# }
# #T_6e1ad_row8_col4 {
#   background-color: #66ff66;
# }
# </style>
# <table id="T_6e1ad">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Comunidade</th>
#       <th id="T_6e1ad_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6e1ad_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_6e1ad_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_6e1ad_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_6e1ad_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_6e1ad_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_6e1ad_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Região</th>
#       <th class="index_name level1" >Porte</th>
#       <th class="index_name level2" >Divisão_Descrição</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e1ad_level0_row0" class="row_heading level0 row0" >Centro_Oeste</th>
#       <th id="T_6e1ad_level1_row0" class="row_heading level1 row0" >ME</th>
#       <th id="T_6e1ad_level2_row0" class="row_heading level2 row0" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_6e1ad_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_6e1ad_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_6e1ad_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_6e1ad_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_6e1ad_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_6e1ad_row0_col5" class="data row0 col5" >16.61%</td>
#       <td id="T_6e1ad_row0_col6" class="data row0 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level0_row1" class="row_heading level0 row1" rowspan="4">Nordeste</th>
#       <th id="T_6e1ad_level1_row1" class="row_heading level1 row1" >EPP</th>
#       <th id="T_6e1ad_level2_row1" class="row_heading level2 row1" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_6e1ad_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_6e1ad_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_6e1ad_row1_col2" class="data row1 col2" >22.65%</td>
#       <td id="T_6e1ad_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_6e1ad_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_6e1ad_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_6e1ad_row1_col6" class="data row1 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level1_row2" class="row_heading level1 row2" rowspan="3">ME</th>
#       <th id="T_6e1ad_level2_row2" class="row_heading level2 row2" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_6e1ad_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_6e1ad_row2_col1" class="data row2 col1" >27.61%</td>
#       <td id="T_6e1ad_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_6e1ad_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_6e1ad_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_6e1ad_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_6e1ad_row2_col6" class="data row2 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level2_row3" class="row_heading level2 row3" >OBRAS DE INFRAESTRUTURA</th>
#       <td id="T_6e1ad_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_6e1ad_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_6e1ad_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_6e1ad_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_6e1ad_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_6e1ad_row3_col5" class="data row3 col5" >0.00%</td>
#       <td id="T_6e1ad_row3_col6" class="data row3 col6" >18.59%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level2_row4" class="row_heading level2 row4" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_6e1ad_row4_col0" class="data row4 col0" >0.00%</td>
#       <td id="T_6e1ad_row4_col1" class="data row4 col1" >0.00%</td>
#       <td id="T_6e1ad_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id="T_6e1ad_row4_col3" class="data row4 col3" >17.29%</td>
#       <td id="T_6e1ad_row4_col4" class="data row4 col4" >0.00%</td>
#       <td id="T_6e1ad_row4_col5" class="data row4 col5" >0.00%</td>
#       <td id="T_6e1ad_row4_col6" class="data row4 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level0_row5" class="row_heading level0 row5" rowspan="4">Sudeste</th>
#       <th id="T_6e1ad_level1_row5" class="row_heading level1 row5" >EPP</th>
#       <th id="T_6e1ad_level2_row5" class="row_heading level2 row5" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_6e1ad_row5_col0" class="data row5 col0" >0.00%</td>
#       <td id="T_6e1ad_row5_col1" class="data row5 col1" >0.00%</td>
#       <td id="T_6e1ad_row5_col2" class="data row5 col2" >37.11%</td>
#       <td id="T_6e1ad_row5_col3" class="data row5 col3" >0.00%</td>
#       <td id="T_6e1ad_row5_col4" class="data row5 col4" >0.00%</td>
#       <td id="T_6e1ad_row5_col5" class="data row5 col5" >0.00%</td>
#       <td id="T_6e1ad_row5_col6" class="data row5 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level1_row6" class="row_heading level1 row6" rowspan="3">ME</th>
#       <th id="T_6e1ad_level2_row6" class="row_heading level2 row6" >CONSTRUÇÃO DE EDIFÍCIOS</th>
#       <td id="T_6e1ad_row6_col0" class="data row6 col0" >0.00%</td>
#       <td id="T_6e1ad_row6_col1" class="data row6 col1" >34.60%</td>
#       <td id="T_6e1ad_row6_col2" class="data row6 col2" >0.00%</td>
#       <td id="T_6e1ad_row6_col3" class="data row6 col3" >0.00%</td>
#       <td id="T_6e1ad_row6_col4" class="data row6 col4" >0.00%</td>
#       <td id="T_6e1ad_row6_col5" class="data row6 col5" >0.00%</td>
#       <td id="T_6e1ad_row6_col6" class="data row6 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level2_row7" class="row_heading level2 row7" >OBRAS DE INFRAESTRUTURA</th>
#       <td id="T_6e1ad_row7_col0" class="data row7 col0" >0.00%</td>
#       <td id="T_6e1ad_row7_col1" class="data row7 col1" >0.00%</td>
#       <td id="T_6e1ad_row7_col2" class="data row7 col2" >0.00%</td>
#       <td id="T_6e1ad_row7_col3" class="data row7 col3" >0.00%</td>
#       <td id="T_6e1ad_row7_col4" class="data row7 col4" >0.00%</td>
#       <td id="T_6e1ad_row7_col5" class="data row7 col5" >0.00%</td>
#       <td id="T_6e1ad_row7_col6" class="data row7 col6" >35.68%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level2_row8" class="row_heading level2 row8" >SERVIÇOS ESPECIALIZADOS PARA CONSTRUÇÃO</th>
#       <td id="T_6e1ad_row8_col0" class="data row8 col0" >37.81%</td>
#       <td id="T_6e1ad_row8_col1" class="data row8 col1" >0.00%</td>
#       <td id="T_6e1ad_row8_col2" class="data row8 col2" >0.00%</td>
#       <td id="T_6e1ad_row8_col3" class="data row8 col3" >45.34%</td>
#       <td id="T_6e1ad_row8_col4" class="data row8 col4" >53.77%</td>
#       <td id="T_6e1ad_row8_col5" class="data row8 col5" >32.13%</td>
#       <td id="T_6e1ad_row8_col6" class="data row8 col6" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_6e1ad_level0_row9" class="row_heading level0 row9" rowspan="3">Sul</th>
#       <th id="T_6e1ad_level1_row9" class="row_heading level1 row9" rowspan="3">ME</th>

# %%
# Contagem de registros por comunidade
contagem_comunidades = df['Comunidade'].value_counts().reset_index()

# Renomear as colunas para clareza
contagem_comunidades.columns = ['Comunidade', 'Count']

# Ordenar pela contagem em ordem decrescente
contagem_comunidades_sorted = contagem_comunidades.sort_values(by='Count', ascending=False)

# Exibir o resultado
contagem_comunidades_sorted
# Out:
#    Comunidade  Count
# 0           0   2740
# 1           1   2003
# 2           3    827
# 3           4    796
# 4           2    671
# 5           5    277
# 6           6    199

# %%
# Calculando a média da centralidade de grau por comunidade, ignorando NaN
media_centralidade = df.groupby('Comunidade', dropna=True)['Centralidade de Grau Ponderada'].mean()

# Exibindo o resultado
print(media_centralidade)
# Out:
# Comunidade
# 0    0.127428
# 1    0.691343
# 2    0.242214
# 3    0.328637
# 4    0.316716
# 5    0.104209
# 6    0.042192
# Name: Centralidade de Grau Ponderada, dtype: float64
